# %%
# Dependencies
from splinter import Browser
from bs4 import BeautifulSoup as bs
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST driver version for 96.0.4664
# Driver [C:\Users\mdebo\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache

# %%
url = 'https://redplanetscience.com/'
browser.visit(url)

# %%
# HTML object
    html = browser.html
    # Parse HTML with Beautiful Soup
    soup = bs(html, 'html.parser')
    # retrieve the most recent news item
    news_item = soup.select_one('div', class_='list_text')

# %%
# Retrieve the most recent news item content, date, title, blurb
news_date = soup.find('div', class_='list_date').get_text()
news_date
# Out:
# 'November 18, 2021'

# %%
news_title = soup.find('div', class_='content_title').get_text()
news_title
# Out:
# 'NASA Invites Public to Share Excitement of Mars 2020 Perseverance Rover Launch'

# %%
news_blurb = soup.find('div', class_='article_teaser_body').get_text()
news_blurb
# Out:
# 'There are lots of ways to participate in the historic event, which is targeted for July 30.'

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST driver version for 96.0.4664
# Driver [C:\Users\mdebo\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache

# %%
#JPL Mars Space Images - Featured Image
url = 'https://spaceimages-mars.com/'
browser.visit(url)

# %%
# HTML object
html = browser.html
# Parse HTML with Beautiful Soup
soup = bs(html, 'html.parser')
# retrieve the most recent news item
#jpl_image = soup.find('div', class_='floating_text_area')

# %%
# Use Beautiful Soup's find() method to navigate and retrieve attributes
# h1 = soup.find('h1', class_='media_feature_title').get_text()
# print(h1)

# %%
#full_image_element = browser.links.find_by_partial_text('FULL IMAGE')
#full_image_element.click()

# %%
soup
# Out:
# <html class=""><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" rel="stylesheet"/>
# <!-- <link rel="stylesheet" type="text/css" href="css/font.css"> -->
# <link href="css/app.css" rel="stylesheet" type="text/css"/>
# <link href="https://stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <title>Space Image</title>
# <style type="text/css">.fancybox-margin{margin-right:16px;}</style></head>
# <body>
# <div class="header">
# <nav class="navbar navbar-expand-lg">
# <a class="navbar-brand" href="#"><img id="logo" src="image/nasa.png"/><span class="logo">Jet Propulsion Laboratory</span>
# <span class="logo1">California Institute of Technology</span></a>
# ...

# %%
featured_image_url = soup.find('img', class_="headerimage")['src']
url+featured_image_url
# Out:
# 'https://spaceimages-mars.com/image/featured/mars1.jpg'

# %%
print(url+featured_image_url)
# Out:
# https://spaceimages-mars.com/image/featured/mars1.jpg

# %%
featured_jpl = soup.find('img', src=True)
featured_jp
# #print image url
# for image in featured_jpl:
#     print(image['src'])
# Out:
# []

# %%
browser.quit()

# %%
#JPL Mars Space Images - Featured Image
url = 'https://spaceimages-mars.com/'
browser.visit(url)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     169             conn = connection.create_connection(
# --> 170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ...

# %%
# HTML object
html = browser.html
# Parse HTML with Beautiful Soup
soup = bs(html, 'html.parser')
# retrieve the most recent news item
jpl_image = soup.find('div', class_='floating_text_area')

# %%
# Use Beautiful Soup's find() method to navigate and retrieve attributes
h1 = soup.find('h1', class_='media_feature_title').get_text()
print(h1)
# Out:
# Dusty Space Cloud

# %%
full_image_element = browser.links.find_by_partial_text('FULL IMAGE')
full_image_element.click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-37-9d6838298caf> in <module>
#       1 full_image_element = browser.links.find_by_partial_text('FULL IMAGE')
# ----> 2 full_image_element.click()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in click(self)
#     823                 error = e
#     824
# --> 825         raise error
#     826
#     827     def check(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in click(self)
#     816         while time.time() < end_time:
#     817             try:
# --> 818                 return self._element.click()
#     819             except(
#     820                 ElementClickInterceptedException,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
# ...

# %%
featured_image_url = soup.find('img', class_="fancybox-image")['src']
featured_image_url

# %%
url = "https://galaxyfacts-mars.com/"
browser.visit(url)

# %%
table = pd.read_html(url)
len(tables)
# Out:
# 2

# %%
mars_table = table[1]
print(mars_table)
# Out:
#                       0                              1
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:          2 ( Phobos & Deimos )
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
combo_table = table[0]
print(combo_table)
# Out:
#                          0                1                2
# 0  Mars - Earth Comparison             Mars            Earth
# 1                Diameter:         6,779 km        12,742 km
# 2                    Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
# 3                   Moons:                2                1
# 4       Distance from Sun:   227,943,824 km   149,598,262 km
# 5          Length of Year:   687 Earth days      365.24 days
# 6             Temperature:     -87 to -5 °C      -88 to 58°C

# %%
# combo_table = combo_table.rename(columns={'1':'Mars', '2':'Earth'})
# combo_table

# %%
print(tables)
# Out:
# [                         0                1                2
# 0  Mars - Earth Comparison             Mars            Earth
# 1                Diameter:         6,779 km        12,742 km
# 2                    Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
# 3                   Moons:                2                1
# 4       Distance from Sun:   227,943,824 km   149,598,262 km
# 5          Length of Year:   687 Earth days      365.24 days
# 6             Temperature:     -87 to -5 °C      -88 to 58°C,                       0                              1
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:          2 ( Phobos & Deimos )
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# ...

# %%
earth_table = pd.DataFrame({'2': ['12,742 km', '12,713.6 km', '5.97×10^24 kg (1.0 Earth)', '1 ( Luna )', '149,597,870 km (1.0 AU)', '365.256 days (1.0 years)', '-89 to 57 °C', 'uhh', 'The monkeys in 2001: A Space Odyssey'], 
                           '3': ['1','2','3','4','5','6','7','15','16']})

# %%
print(earth_table)
# Out:
#                                       2   3
# 0                             12,742 km   1
# 1                           12,713.6 km   2
# 2             5.97×10^24 kg (1.0 Earth)   3
# 3                            1 ( Luna )   4
# 4               149,597,870 km (1.0 AU)   5
# 5              365.256 days (1.0 years)   6
# 6                          -89 to 57 °C   7
# 7                                   uhh  15
# 8  The monkeys in 2001: A Space Odyssey  16

# %%
join_1 = mars_table.merge(right=earth_table, how="outer", left_index=True, right_index=True)
join_1
# Out:
#                       0                              1  \
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:          2 ( Phobos & Deimos )
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers
#
#                                       2   3
# 0                             12,742 km   1
# 1                           12,713.6 km   2
# 2             5.97×10^24 kg (1.0 Earth)   3
# 3                            1 ( Luna )   4
# 4               149,597,870 km (1.0 AU)   5
# 5              365.256 days (1.0 years)   6
# 6                          -89 to 57 °C   7
# 7                                   uhh  15
# ...

# %%
join_1 = join_1.set_index('3')
join_1
# Out:
#                        0                              1  \
# 3
# 1   Equatorial Diameter:                       6,792 km
# 2        Polar Diameter:                       6,752 km
# 3                  Mass:  6.39 × 10^23 kg (0.11 Earths)
# 4                 Moons:          2 ( Phobos & Deimos )
# 5        Orbit Distance:       227,943,824 km (1.38 AU)
# 6          Orbit Period:           687 days (1.9 years)
# 7   Surface Temperature:                   -87 to -5 °C
# 15         First Record:              2nd millennium BC
# 16          Recorded By:           Egyptian astronomers
#
#                                        2
# 3
# 1                              12,742 km
# 2                            12,713.6 km
# 3              5.97×10^24 kg (1.0 Earth)
# 4                             1 ( Luna )
# 5                149,597,870 km (1.0 AU)
# 6               365.256 days (1.0 years)
# 7                           -89 to 57 °C
# 15                                   uhh
# ...

# %%
dataframe = join_1.merge(combo_table, how='left', left_index=True, right_index=True)
dataframe
# Out:
#                      0_x                            1_x  \
# 3
# 1   Equatorial Diameter:                       6,792 km
# 2        Polar Diameter:                       6,752 km
# 3                  Mass:  6.39 × 10^23 kg (0.11 Earths)
# 4                 Moons:          2 ( Phobos & Deimos )
# 5        Orbit Distance:       227,943,824 km (1.38 AU)
# 6          Orbit Period:           687 days (1.9 years)
# 7   Surface Temperature:                   -87 to -5 °C
# 15         First Record:              2nd millennium BC
# 16          Recorded By:           Egyptian astronomers
#
#                                        2  0_y  1_y    2
# 3
# 1                              12,742 km  NaN  NaN  NaN
# 2                            12,713.6 km  NaN  NaN  NaN
# 3              5.97×10^24 kg (1.0 Earth)  NaN  NaN  NaN
# 4                             1 ( Luna )  NaN  NaN  NaN
# 5                149,597,870 km (1.0 AU)  NaN  NaN  NaN
# 6               365.256 days (1.0 years)  NaN  NaN  NaN
# ...

# %%
dataframe = dataframe.reset_index()
dataframe
# Out:
#     3                   0_x                            1_x  \
# 0   1  Equatorial Diameter:                       6,792 km
# 1   2       Polar Diameter:                       6,752 km
# 2   3                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3   4                Moons:          2 ( Phobos & Deimos )
# 4   5       Orbit Distance:       227,943,824 km (1.38 AU)
# 5   6         Orbit Period:           687 days (1.9 years)
# 6   7  Surface Temperature:                   -87 to -5 °C
# 7  15         First Record:              2nd millennium BC
# 8  16          Recorded By:           Egyptian astronomers
#
#                                       2  0_y  1_y    2
# 0                             12,742 km  NaN  NaN  NaN
# 1                           12,713.6 km  NaN  NaN  NaN
# 2             5.97×10^24 kg (1.0 Earth)  NaN  NaN  NaN
# 3                            1 ( Luna )  NaN  NaN  NaN
# 4               149,597,870 km (1.0 AU)  NaN  NaN  NaN
# ...

# %%
dataframe = dataframe.drop('3', 1)
dataframe
# Out:
#                     0_x                            1_x  \
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:          2 ( Phobos & Deimos )
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers
#
#                                       2  0_y  1_y    2
# 0                             12,742 km  NaN  NaN  NaN
# 1                           12,713.6 km  NaN  NaN  NaN
# 2             5.97×10^24 kg (1.0 Earth)  NaN  NaN  NaN
# 3                            1 ( Luna )  NaN  NaN  NaN
# 4               149,597,870 km (1.0 AU)  NaN  NaN  NaN
# 5              365.256 days (1.0 years)  NaN  NaN  NaN
# ...

# %%
dataframe = dataframe.drop('0_y', 1)
dataframe
# Out:
#                     0_x                            1_x  \
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:          2 ( Phobos & Deimos )
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers
#
#                                       2  1_y    2
# 0                             12,742 km  NaN  NaN
# 1                           12,713.6 km  NaN  NaN
# 2             5.97×10^24 kg (1.0 Earth)  NaN  NaN
# 3                            1 ( Luna )  NaN  NaN
# 4               149,597,870 km (1.0 AU)  NaN  NaN
# 5              365.256 days (1.0 years)  NaN  NaN
# 6                          -89 to 57 °C  NaN  NaN
# ...

# %%
dataframe = dataframe.drop('1_y', 1)
dataframe
# Out:
#                     0_x                            1_x  \
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:          2 ( Phobos & Deimos )
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers
#
#                                       2    2
# 0                             12,742 km  NaN
# 1                           12,713.6 km  NaN
# 2             5.97×10^24 kg (1.0 Earth)  NaN
# 3                            1 ( Luna )  NaN
# 4               149,597,870 km (1.0 AU)  NaN
# 5              365.256 days (1.0 years)  NaN
# 6                          -89 to 57 °C  NaN
# 7                                   uhh  NaN
# ...

# %%
dataframe = dataframe.rename(columns={'0_x': '', '1_x': 'Mars', '2': 'Earth', '2': '3'})

# %%
dataframe = dataframe.rename(columns={'3': 'Earth'})

# %%
dataframe
# Out:
#                                                   Mars  \
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:          2 ( Phobos & Deimos )
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers
#
#                                   Earth    2
# 0                             12,742 km  NaN
# 1                           12,713.6 km  NaN
# 2             5.97×10^24 kg (1.0 Earth)  NaN
# 3                            1 ( Luna )  NaN
# 4               149,597,870 km (1.0 AU)  NaN
# 5              365.256 days (1.0 years)  NaN
# 6                          -89 to 57 °C  NaN
# 7                                   uhh  NaN
# ...

# %%
dataframe = dataframe.drop(columns=dataframe.columns[3])
dataframe
# Out:
#                                                   Mars  \
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:          2 ( Phobos & Deimos )
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers
#
#                                   Earth
# 0                             12,742 km
# 1                           12,713.6 km
# 2             5.97×10^24 kg (1.0 Earth)
# 3                            1 ( Luna )
# 4               149,597,870 km (1.0 AU)
# 5              365.256 days (1.0 years)
# 6                          -89 to 57 °C
# 7                                   uhh
# 8  The monkeys in 2001: A Space Odyssey

# %%
html_table = df.to_html()
print(html_table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1_x</th>
#       <th>2</th>
#       <th>1_y</th>
#       <th>Earth</th>
#     </tr>
#     <tr>
#       <th>0</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Equatorial Diameter:</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>6,792 km</td>
#       <td>12,742 km</td>
#     </tr>
#     <tr>
#       <th>Polar Diameter:</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>6,752 km</td>
#       <td>12,713.6 km</td>
#     </tr>
#     <tr>
#       <th>Mass:</th>
#       <td>6.39 × 10^23 kg</td>
#       <td>5.97 × 10^24 kg</td>
#       <td>6.39 × 10^23 kg (0.11 Earths)</td>
#       <td>5.97×10^24 kg (1.0 Earth)</td>
#     </tr>
#     <tr>
#       <th>Moons:</th>
#       <td>2</td>
#       <td>1</td>
#       <td>2 ( Phobos &amp; Deimos )</td>
#       <td>1 ( Luna )</td>
# ...

# %%
html_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>1_x</th>      <th>2</th>      <th>1_y</th>      <th>Earth</th>    </tr>    <tr>      <th>0</th>      <th></th>      <th></th>      <th></th>      <th></th>    </tr>  </thead>  <tbody>    <tr>      <th>Equatorial Diameter:</th>      <td>NaN</td>      <td>NaN</td>      <td>6,792 km</td>      <td>12,742 km</td>    </tr>    <tr>      <th>Polar Diameter:</th>      <td>NaN</td>      <td>NaN</td>      <td>6,752 km</td>      <td>12,713.6 km</td>    </tr>    <tr>      <th>Mass:</th>      <td>6.39 × 10^23 kg</td>      <td>5.97 × 10^24 kg</td>      <td>6.39 × 10^23 kg (0.11 Earths)</td>      <td>5.97×10^24 kg (1.0 Earth)</td>    </tr>    <tr>      <th>Moons:</th>      <td>2</td>      <td>1</td>      <td>2 ( Phobos &amp; Deimos )</td>      <td>1 ( Luna )</td>    </tr>    <tr>      <th>Orbit Distance:</th>      <td>NaN</td>      <td>NaN</td>      <td>227,943,824 km (1.38 AU)</td>      <td>149
# ...

# %%
df.to_html('table.html')

# %%
print(dataframe)
# Out:
# None
